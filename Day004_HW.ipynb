# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"12693297004","type":"PushEvent","actor":{"id":16689956,"login":"kamilwojcik","display_login":"kamilwojcik","gravatar_id":"","url":"https://api.github.com/users/kamilwojcik","avatar_url":"https://avatars.githubusercontent.com/u/16689956?"},"repo":{"id":269637563,"name":"kamilwojcik/cfluxim","url":"https://api.github.com/repos/kamilwojcik/cfluxim"},"payload":{"push_id":5262913680,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"36ac37c6fc8e16a4fd6d7e314f487df282a3db91","before":"26a2a7b278dadfe7881580f1084eb2c15b60ef55","commits":[{"sha":"36ac37c6fc8e16a4fd6d7e314f487df282a3db91","author":{"email":"kamil@h204.nuph.us.edu.pl","name":"Kamil Wójcik"},"message":"readme update","distinct":true,"url":"https://api.github.com/repos/kamilwojcik/cfluxim/commits/36ac37c6fc8e16a4fd6d7e314f487df282a3db91"}]},"public":true,"created_at":"2020-06-22T02:48:53Z"},{"id":"12693297009","type":"ForkEvent","actor":{"id":1926185,"login":"RobberPhex","display_login":"RobberPhex","gravatar_id":"","url":"https://api.github.com/users/RobberPhex","avatar_url":"https://avatars.githubusercontent.com/u/1926185?"},"repo":{"id":221862,"name":"rzwitserloot/lombok","url":"https://api.github.com/repos/rzwitserloot/lombok"},"payload":{"forkee":{"id":274024981,"node_id":"MDEwOlJlcG9zaXRvcnkyNzQwMjQ5ODE=","name":"lombok","full_name":"RobberPhex/lombok","private":false,"owner":{"login":"RobberPhex","id":1926185,"node_id":"MDQ6VXNlcjE5MjYxODU=","avatar_url":"https://avatars1.githubusercontent.com/u/1926185?v=4","gravatar_id":"","url":"https://api.github.com/users/RobberPhex","html_url":"https://github.com/RobberPhex","followers_url":"https://api.github.com/users/RobberPhex/followers","following_url":"https://api.github.com/users/RobberPhex/following{/other_user}","gists_url":"https://api.github.com/users/RobberPhex/gists{/gist_id}","starred_url":"https://api.github.com/users/RobberPhex/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/RobberPhex/subscriptions","organizations_url":"https://api.github.com/users/RobberPhex/orgs","repos_url":"https://api.github.com/users/RobberPhex/repos","events_url":"https://api.github.com/users/RobberPhex/events{/privacy}","received_events_url":"https://api.github.com/users/RobberPhex/received_events","type":"User","site_admin":false},"html_url":"https://github.com/RobberPhex/lombok","description":"Very spicy additions to the Java programming language.","fork":true,"url":"https://api.github.com/repos/RobberPhex/lombok","forks_url":"https://api.github.com/repos/RobberPhex/lombok/forks","keys_url":"https://api.github.com/repos/RobberPhex/lombok/keys{/key_id}","collaborators_url":"https://api.github.com/repos/RobberPhex/lombok/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/RobberPhex/lombok/teams","hooks_url":"https://api.github.com/repos/RobberPhex/lombok/hooks","issue_events_url":"https://api.github.com/repos/RobberPhex/lombok/issues/events{/number}","events_url":"https://api.github.com/repos/RobberPhex/lombok/events","assignees_url":"https://api.github.com/repos/RobberPhex/lombok/assignees{/user}","branches_url":"https://api.github.com/repos/RobberPhex/lombok/branches{/branch}","tags_url":"https://api.github.com/repos/RobberPhex/lombok/tags","blobs_url":"https://api.github.com/repos/RobberPhex/lombok/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/RobberPhex/lombok/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/RobberPhex/lombok/git/refs{/sha}","trees_url":"https://api.github.com/repos/RobberPhex/lombok/git/trees{/sha}","statuses_url":"https://api.github.com/repos/RobberPhex/lombok/statuses/{sha}","languages_url":"https://api.github.com/repos/RobberPhex/lombok/languages","stargazers_url":"https://api.github.com/repos/RobberPhex/lombok/stargazers","contributors_url":"https://api.github.com/repos/RobberPhex/lombok/contributors","subscribers_url":"https://api.github.com/repos/RobberPhex/lombok/subscribers","subscription_url":"https://api.github ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '12693297004',
#   'type': 'PushEvent',
#   'actor': {'id': 16689956,
#    'login': 'kamilwojcik',
#    'display_login': 'kamilwojcik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kamilwojcik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16689956?'},
#   'repo': {'id': 269637563,
#    'name': 'kamilwojcik/cfluxim',
#    'url': 'https://api.github.com/repos/kamilwojcik/cfluxim'},
#   'payload': {'push_id': 5262913680,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '36ac37c6fc8e16a4fd6d7e314f487df282a3db91',
#    'before': '26a2a7b278dadfe7881580f1084eb2c15b60ef55',
#    'commits': [{'sha': '36ac37c6fc8e16a4fd6d7e314f487df282a3db91',
#      'author': {'email': 'kamil@h204.nuph.us.edu.pl', 'name': 'Kamil Wójcik'},
#      'message': 'readme update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kamilwojcik/cfluxim/commits/36ac37c6fc8e16a4fd6d7e314f487df282a3db91'}]},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z'},
#  {'id': '12693297009',
#   'type': 'ForkEvent',
#   'actor': {'id': 1926185,
#    'login': 'RobberPhex',
#    'display_login': 'RobberPhex',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RobberPhex',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1926185?'},
#   'repo': {'id': 221862,
#    'name': 'rzwitserloot/lombok',
#    'url': 'https://api.github.com/repos/rzwitserloot/lombok'},
#   'payload': {'forkee': {'id': 274024981,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNzQwMjQ5ODE=',
#     'name': 'lombok',
#     'full_name': 'RobberPhex/lombok',
#     'private': False,
#     'owner': {'login': 'RobberPhex',
#      'id': 1926185,
#      'node_id': 'MDQ6VXNlcjE5MjYxODU=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/1926185?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/RobberPhex',
#      'html_url': 'https://github.com/RobberPhex',
#      'followers_url': 'https://api.github.com/users/RobberPhex/followers',
#      'following_url': 'https://api.github.com/users/RobberPhex/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/RobberPhex/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/RobberPhex/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/RobberPhex/subscriptions',
#      'organizations_url': 'https://api.github.com/users/RobberPhex/orgs',
#      'repos_url': 'https://api.github.com/users/RobberPhex/repos',
#      'events_url': 'https://api.github.com/users/RobberPhex/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/RobberPhex/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/RobberPhex/lombok',
#     'description': 'Very spicy additions to the Java programming language.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/RobberPhex/lombok',
#     'forks_url': 'https://api.github.com/repos/RobberPhex/lombok/forks',
#     'keys_url': 'https://api.github.com/repos/RobberPhex/lombok/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/RobberPhex/lombok/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/RobberPhex/lombok/teams',
#     'hooks_url': 'https://api.github.com/repos/RobberPhex/lombok/hooks',
#     'issue_events_url': 'https://api.github.com/repos/RobberPhex/lombok/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/RobberPhex/lombok/events',
#     'assignees_url': 'https://api.github.com/repos/RobberPhex/lombok/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/RobberPhex/lombok/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/RobberPhex/lombok/tags',
#     'blobs_url': 'https://api.github.com/repos/RobberPhex/lombok/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/RobberPhex/lombok/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/RobberPhex/lombok/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/RobberPhex/lombok/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/RobberPhex/lombok/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/RobberPhex/lombok/languages',
#     'stargazers_url': 'https://api.github.com/repos/RobberPhex/lombok/stargazers',
#     'contributors_url': 'https://api.github.com/repos/RobberPhex/lombok/contributors',
#     'subscribers_url': 'https://api.github.com/repos/RobberPhex/lombok/subscribers',
#     'subscription_url': 'https://api.github.com/repos/RobberPhex/lombok/subscription',
#     'commits_url': 'https://api.github.com/repos/RobberPhex/lombok/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/RobberPhex/lombok/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/RobberPhex/lombok/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/RobberPhex/lombok/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/RobberPhex/lombok/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/RobberPhex/lombok/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/RobberPhex/lombok/merges',
#     'archive_url': 'https://api.github.com/repos/RobberPhex/lombok/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/RobberPhex/lombok/downloads',
#     'issues_url': 'https://api.github.com/repos/RobberPhex/lombok/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/RobberPhex/lombok/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/RobberPhex/lombok/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/RobberPhex/lombok/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/RobberPhex/lombok/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/RobberPhex/lombok/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/RobberPhex/lombok/deployments',
#     'created_at': '2020-06-22T02:48:52Z',
#     'updated_at': '2020-06-22T01:58:06Z',
#     'pushed_at': '2020-06-18T22:49:05Z',
#     'git_url': 'git://github.com/RobberPhex/lombok.git',
#     'ssh_url': 'git@github.com:RobberPhex/lombok.git',
#     'clone_url': 'https://github.com/RobberPhex/lombok.git',
#     'svn_url': 'https://github.com/RobberPhex/lombok',
#     'homepage': 'https://projectlombok.org/',
#     'size': 76643,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': False,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z'},
#  {'id': '12693297003',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 7167597,
#    'name': 'elabftw/elabftw',
#    'url': 'https://api.github.com/repos/elabftw/elabftw'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/elabftw/elabftw/issues/1997',
#     'repository_url': 'https://api.github.com/repos/elabftw/elabftw',
#     'labels_url': 'https://api.github.com/repos/elabftw/elabftw/issues/1997/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/elabftw/elabftw/issues/1997/comments',
#     'events_url': 'https://api.github.com/repos/elabftw/elabftw/issues/1997/events',
#     'html_url': 'https://github.com/elabftw/elabftw/pull/1997',
#     'id': 638499704,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDM0MjU0NjA3',
#     'number': 1997,
#     'title': 'Bump symfony/process from 5.1.0 to 5.1.1',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 680422832,
#       'node_id': 'MDU6TGFiZWw2ODA0MjI4MzI=',
#       'url': 'https://api.github.com/repos/elabftw/elabftw/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0025ff',
#       'default': False,
#       'description': None},
#      {'id': 1038647036,
#       'node_id': 'MDU6TGFiZWwxMDM4NjQ3MDM2',
#       'url': 'https://api.github.com/repos/elabftw/elabftw/labels/php',
#       'name': 'php',
#       'color': '45229e',
#       'default': False,
#       'description': 'Pull requests that update Php code'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-06-15T02:49:07Z',
#     'updated_at': '2020-06-22T02:48:53Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/elabftw/elabftw/pulls/1997',
#      'html_url': 'https://github.com/elabftw/elabftw/pull/1997',
#      'diff_url': 'https://github.com/elabftw/elabftw/pull/1997.diff',
#      'patch_url': 'https://github.com/elabftw/elabftw/pull/1997.patch'},
#     'body': 'Bumps [symfony/process](https://github.com/symfony/process) from 5.1.0 to 5.1.1.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/symfony/process/releases">symfony/process\'s releases</a>.</em></p>\n<blockquote>\n<h2>v5.1.1</h2>\n<p><strong>Changelog</strong> (<a href="https://github.com/symfony/process/compare/v5.1.0...v5.1.1">https://github.com/symfony/process/compare/v5.1.0...v5.1.1</a>)</p>\n<ul>\n<li>no changes</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/symfony/process/blob/master/CHANGELOG.md">symfony/process\'s changelog</a>.</em></p>\n<blockquote>\n<h1>CHANGELOG</h1>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li>See full diff in <a href="https://github.com/symfony/process/compare/v5.1.0...v5.1.1">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=symfony/process&package-manager=composer&previous-version=5.1.0&new-version=5.1.1)](https://dependabot.com/compatibility-score/?dependency-name=symfony/process&package-manager=composer&previous-version=5.1.0&new-version=5.1.1)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot badge me` will comment on this PR with code to add a "Dependabot enabled" badge to your readme\n\nAdditionally, you can set the following in the `.dependabot/config.yml` file in this repo:\n- Update frequency\n- Automerge options (never/patch/minor, and dev/runtime dependencies)\n- Out-of-range updates (receive only lockfile updates, if desired)\n- Security updates (receive only security updates, if desired)\n\n\n\n</details>'},
#    'comment': {'url': 'https://api.github.com/repos/elabftw/elabftw/issues/comments/647238599',
#     'html_url': 'https://github.com/elabftw/elabftw/pull/1997#issuecomment-647238599',
#     'issue_url': 'https://api.github.com/repos/elabftw/elabftw/issues/1997',
#     'id': 647238599,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY0NzIzODU5OQ==',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-06-22T02:48:53Z',
#     'updated_at': '2020-06-22T02:48:53Z',
#     'author_association': 'NONE',
#     'body': 'Superseded by #2009.'}},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z',
#   'org': {'id': 7669213,
#    'login': 'elabftw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/elabftw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7669213?'}},
#  {'id': '12693297005',
#   'type': 'DeleteEvent',
#   'actor': {'id': 670100,
#    'login': 'mathieugagne',
#    'display_login': 'mathieugagne',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mathieugagne',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/670100?'},
#   'repo': {'id': 272039282,
#    'name': 'melonmiel/breakout',
#    'url': 'https://api.github.com/repos/melonmiel/breakout'},
#   'payload': {'ref': 'adds-engine-settings',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z',
#   'org': {'id': 66860690,
#    'login': 'melonmiel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/melonmiel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66860690?'}},
#  {'id': '12693297002',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 211115199,
#    'name': 'geo6/php-acl-access',
#    'url': 'https://api.github.com/repos/geo6/php-acl-access'},
#   'payload': {'ref': 'dependabot/composer/guzzlehttp/guzzle-6.5.5',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z',
#   'org': {'id': 24525622,
#    'login': 'geo6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/geo6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24525622?'}},
#  {'id': '12693296981',
#   'type': 'PushEvent',
#   'actor': {'id': 66241426,
#    'login': 'genkimita',
#    'display_login': 'genkimita',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/genkimita',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66241426?'},
#   'repo': {'id': 271694722,
#    'name': 'genkimita/mosya_matukazeya',
#    'url': 'https://api.github.com/repos/genkimita/mosya_matukazeya'},
#   'payload': {'push_id': 5262913671,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a6f4eaf82f43b0eb5ebbe43d153477551190453c',
#    'before': 'f8836198c24795019d6e666db0e5de49c9a66ee1',
#    'commits': [{'sha': 'a6f4eaf82f43b0eb5ebbe43d153477551190453c',
#      'author': {'email': '66241426+genkimita@users.noreply.github.com',
#       'name': 'genkimita'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/genkimita/mosya_matukazeya/commits/a6f4eaf82f43b0eb5ebbe43d153477551190453c'}]},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z'},
#  {'id': '12693297001',
#   'type': 'CreateEvent',
#   'actor': {'id': 67197606,
#    'login': 'mlssystem',
#    'display_login': 'mlssystem',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mlssystem',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67197606?'},
#   'repo': {'id': 274024984,
#    'name': 'mlssystem/testando',
#    'url': 'https://api.github.com/repos/mlssystem/testando'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Recriando o site trabalhadores da seara',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z'},
#  {'id': '12693297000',
#   'type': 'WatchEvent',
#   'actor': {'id': 42022475,
#    'login': 'machentian',
#    'display_login': 'machentian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/machentian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42022475?'},
#   'repo': {'id': 89670974,
#    'name': 'lanux/Vue-Admin',
#    'url': 'https://api.github.com/repos/lanux/Vue-Admin'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z'},
#  {'id': '12693296970',
#   'type': 'PushEvent',
#   'actor': {'id': 21973335,
#    'login': 'tommy605',
#    'display_login': 'tommy605',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tommy605',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21973335?'},
#   'repo': {'id': 274005085,
#    'name': 'tommy605/Tesla',
#    'url': 'https://api.github.com/repos/tommy605/Tesla'},
#   'payload': {'push_id': 5262913667,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1176e947a3fe1c582ea7bbbb2e69583af3f3c3f1',
#    'before': '140051c89748ef42bba30e7756e6f3faf0230b80',
#    'commits': [{'sha': '1176e947a3fe1c582ea7bbbb2e69583af3f3c3f1',
#      'author': {'email': 'thubert@rogers.com', 'name': 'tommy605'},
#      'message': 'GIT CloneShare Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tommy605/Tesla/commits/1176e947a3fe1c582ea7bbbb2e69583af3f3c3f1'}]},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z'},
#  {'id': '12693296972',
#   'type': 'PushEvent',
#   'actor': {'id': 670100,
#    'login': 'mathieugagne',
#    'display_login': 'mathieugagne',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mathieugagne',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/670100?'},
#   'repo': {'id': 272039282,
#    'name': 'melonmiel/breakout',
#    'url': 'https://api.github.com/repos/melonmiel/breakout'},
#   'payload': {'push_id': 5262913669,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '665609fc034a087b8c6fbd0137b8227d96f68ccd',
#    'before': 'f579f29ec675452758b89f19efd35f1656c63036',
#    'commits': [{'sha': '665609fc034a087b8c6fbd0137b8227d96f68ccd',
#      'author': {'email': 'gagne.mathieu@hotmail.com', 'name': 'Mathieu Gagné'},
#      'message': 'Adds Settings (#43)\n\n* Adds Engine::Settings\r\n\r\n* Adds Settings',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/melonmiel/breakout/commits/665609fc034a087b8c6fbd0137b8227d96f68ccd'}]},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z',
#   'org': {'id': 66860690,
#    'login': 'melonmiel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/melonmiel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66860690?'}},
#  {'id': '12693296999',
#   'type': 'ForkEvent',
#   'actor': {'id': 21231495,
#    'login': 'daniel-007',
#    'display_login': 'daniel-007',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daniel-007',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21231495?'},
#   'repo': {'id': 196979364,
#    'name': 'bigfile/bigfile',
#    'url': 'https://api.github.com/repos/bigfile/bigfile'},
#   'payload': {'forkee': {'id': 274024982,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyNzQwMjQ5ODI=',
#     'name': 'bigfile',
#     'full_name': 'daniel-007/bigfile',
#     'private': False,
#     'owner': {'login': 'daniel-007',
#      'id': 21231495,
#      'node_id': 'MDQ6VXNlcjIxMjMxNDk1',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/21231495?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/daniel-007',
#      'html_url': 'https://github.com/daniel-007',
#      'followers_url': 'https://api.github.com/users/daniel-007/followers',
#      'following_url': 'https://api.github.com/users/daniel-007/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/daniel-007/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/daniel-007/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/daniel-007/subscriptions',
#      'organizations_url': 'https://api.github.com/users/daniel-007/orgs',
#      'repos_url': 'https://api.github.com/users/daniel-007/repos',
#      'events_url': 'https://api.github.com/users/daniel-007/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/daniel-007/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/daniel-007/bigfile',
#     'description': 'Bigfile -- a file transfer system that supports http, rpc and ftp protocol   https://bigfile.site  ',
#     'fork': True,
#     'url': 'https://api.github.com/repos/daniel-007/bigfile',
#     'forks_url': 'https://api.github.com/repos/daniel-007/bigfile/forks',
#     'keys_url': 'https://api.github.com/repos/daniel-007/bigfile/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/daniel-007/bigfile/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/daniel-007/bigfile/teams',
#     'hooks_url': 'https://api.github.com/repos/daniel-007/bigfile/hooks',
#     'issue_events_url': 'https://api.github.com/repos/daniel-007/bigfile/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/daniel-007/bigfile/events',
#     'assignees_url': 'https://api.github.com/repos/daniel-007/bigfile/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/daniel-007/bigfile/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/daniel-007/bigfile/tags',
#     'blobs_url': 'https://api.github.com/repos/daniel-007/bigfile/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/daniel-007/bigfile/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/daniel-007/bigfile/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/daniel-007/bigfile/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/daniel-007/bigfile/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/daniel-007/bigfile/languages',
#     'stargazers_url': 'https://api.github.com/repos/daniel-007/bigfile/stargazers',
#     'contributors_url': 'https://api.github.com/repos/daniel-007/bigfile/contributors',
#     'subscribers_url': 'https://api.github.com/repos/daniel-007/bigfile/subscribers',
#     'subscription_url': 'https://api.github.com/repos/daniel-007/bigfile/subscription',
#     'commits_url': 'https://api.github.com/repos/daniel-007/bigfile/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/daniel-007/bigfile/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/daniel-007/bigfile/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/daniel-007/bigfile/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/daniel-007/bigfile/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/daniel-007/bigfile/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/daniel-007/bigfile/merges',
#     'archive_url': 'https://api.github.com/repos/daniel-007/bigfile/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/daniel-007/bigfile/downloads',
#     'issues_url': 'https://api.github.com/repos/daniel-007/bigfile/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/daniel-007/bigfile/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/daniel-007/bigfile/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/daniel-007/bigfile/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/daniel-007/bigfile/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/daniel-007/bigfile/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/daniel-007/bigfile/deployments',
#     'created_at': '2020-06-22T02:48:52Z',
#     'updated_at': '2020-06-22T02:08:55Z',
#     'pushed_at': '2020-02-26T01:29:46Z',
#     'git_url': 'git://github.com/daniel-007/bigfile.git',
#     'ssh_url': 'git@github.com:daniel-007/bigfile.git',
#     'clone_url': 'https://github.com/daniel-007/bigfile.git',
#     'svn_url': 'https://github.com/daniel-007/bigfile',
#     'homepage': 'https://learnku.com/docs/bigfile',
#     'size': 548,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z',
#   'org': {'id': 52916753,
#    'login': 'bigfile',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bigfile',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52916753?'}},
#  {'id': '12693296966',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 59370141,
#    'login': 'miobada',
#    'display_login': 'miobada',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/miobada',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59370141?'},
#   'repo': {'id': 156695034,
#    'name': 'inspireui/support',
#    'url': 'https://api.github.com/repos/inspireui/support'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/inspireui/support/issues/3844',
#     'repository_url': 'https://api.github.com/repos/inspireui/support',
#     'labels_url': 'https://api.github.com/repos/inspireui/support/issues/3844/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/inspireui/support/issues/3844/comments',
#     'events_url': 'https://api.github.com/repos/inspireui/support/issues/3844/events',
#     'html_url': 'https://github.com/inspireui/support/issues/3844',
#     'id': 642646395,
#     'node_id': 'MDU6SXNzdWU2NDI2NDYzOTU=',
#     'number': 3844,
#     'title': 'Fluxstore Mv . Social login nor give user his role',
#     'user': {'login': 'abedfatafta',
#      'id': 16276919,
#      'node_id': 'MDQ6VXNlcjE2Mjc2OTE5',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/16276919?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/abedfatafta',
#      'html_url': 'https://github.com/abedfatafta',
#      'followers_url': 'https://api.github.com/users/abedfatafta/followers',
#      'following_url': 'https://api.github.com/users/abedfatafta/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/abedfatafta/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/abedfatafta/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/abedfatafta/subscriptions',
#      'organizations_url': 'https://api.github.com/users/abedfatafta/orgs',
#      'repos_url': 'https://api.github.com/users/abedfatafta/repos',
#      'events_url': 'https://api.github.com/users/abedfatafta/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/abedfatafta/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1667819696,
#       'node_id': 'MDU6TGFiZWwxNjY3ODE5Njk2',
#       'url': 'https://api.github.com/repos/inspireui/support/labels/FluxstoreMV',
#       'name': 'FluxstoreMV',
#       'color': '463696',
#       'default': False,
#       'description': ''},
#      {'id': 1834371668,
#       'node_id': 'MDU6TGFiZWwxODM0MzcxNjY4',
#       'url': 'https://api.github.com/repos/inspireui/support/labels/Mstore-API',
#       'name': 'Mstore-API',
#       'color': '3691c9',
#       'default': False,
#       'description': ''},
#      {'id': 1120523787,
#       'node_id': 'MDU6TGFiZWwxMTIwNTIzNzg3',
#       'url': 'https://api.github.com/repos/inspireui/support/labels/feature-request%20%F0%9F%86%95',
#       'name': 'feature-request 🆕',
#       'color': '6918db',
#       'default': False,
#       'description': 'New feature or request'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'minhtruong315',
#      'id': 10402500,
#      'node_id': 'MDQ6VXNlcjEwNDAyNTAw',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/10402500?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/minhtruong315',
#      'html_url': 'https://github.com/minhtruong315',
#      'followers_url': 'https://api.github.com/users/minhtruong315/followers',
#      'following_url': 'https://api.github.com/users/minhtruong315/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/minhtruong315/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/minhtruong315/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/minhtruong315/subscriptions',
#      'organizations_url': 'https://api.github.com/users/minhtruong315/orgs',
#      'repos_url': 'https://api.github.com/users/minhtruong315/repos',
#      'events_url': 'https://api.github.com/users/minhtruong315/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/minhtruong315/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'minhtruong315',
#       'id': 10402500,
#       'node_id': 'MDQ6VXNlcjEwNDAyNTAw',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/10402500?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/minhtruong315',
#       'html_url': 'https://github.com/minhtruong315',
#       'followers_url': 'https://api.github.com/users/minhtruong315/followers',
#       'following_url': 'https://api.github.com/users/minhtruong315/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/minhtruong315/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/minhtruong315/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/minhtruong315/subscriptions',
#       'organizations_url': 'https://api.github.com/users/minhtruong315/orgs',
#       'repos_url': 'https://api.github.com/users/minhtruong315/repos',
#       'events_url': 'https://api.github.com/users/minhtruong315/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/minhtruong315/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-06-21T21:43:12Z',
#     'updated_at': '2020-06-22T02:48:53Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': "**_Step 1 (require): describe detail issues & screenshots_**\r\n+ Detail Issues: \r\nWhen you social login with facebook ,sms,google  app must fetch role and behave on that role . Currently its give default user .\r\nSo when vendor use social login he didn't get vendor role like add product and my products \r\n+ Product & version:1.7.5\r\n+ Flutter (or React Native) version: latest\r\n+ Testing Device/Simulator: android \r\n+ Screenshot issues (drag the file to attach here): \r\n\r\n\r\nCan i get fix out of core update ?\r\n\r\n\r\n**_Step 2 (require): submit proof of purchasing the license on http://verify.inspireui.com_**\r\n\r\nOld ticket #3349\r\n\r\n\r\n\r\n**_Important Note:_**\r\n- We will close the ticket if missing the proof of purchase on step 2. The screenshot purchase attaches here will be invalid.\r\n- Kindly create only *One Ticket* & includes all the issues, that would help us focus to resolve it better. \r\n- If your all ticket was resolved & closed, but want to create a new ticket, just do simple step by linking to the previous verified ID (you don't need to submit the form again), for example, #Ticket-ID\r\n\r\nThank you so much for your time 😊\r\n"},
#    'comment': {'url': 'https://api.github.com/repos/inspireui/support/issues/comments/647238596',
#     'html_url': 'https://github.com/inspireui/support/issues/3844#issuecomment-647238596',
#     'issue_url': 'https://api.github.com/repos/inspireui/support/issues/3844',
#     'id': 647238596,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY0NzIzODU5Ng==',
#     'user': {'login': 'miobada',
#      'id': 59370141,
#      'node_id': 'MDQ6VXNlcjU5MzcwMTQx',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/59370141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/miobada',
#      'html_url': 'https://github.com/miobada',
#      'followers_url': 'https://api.github.com/users/miobada/followers',
#      'following_url': 'https://api.github.com/users/miobada/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/miobada/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/miobada/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/miobada/subscriptions',
#      'organizations_url': 'https://api.github.com/users/miobada/orgs',
#      'repos_url': 'https://api.github.com/users/miobada/repos',
#      'events_url': 'https://api.github.com/users/miobada/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/miobada/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-06-22T02:48:52Z',
#     'updated_at': '2020-06-22T02:48:52Z',
#     'author_association': 'NONE',
#     'body': "![Screenshot_1](https://user-images.githubusercontent.com/59370141/85243977-b447ae00-b419-11ea-9e36-bec660ed9791.jpg)\r\n\r\n\r\n* What went wrong:\r\nCould not determine the dependencies of task ':app_settings:compileDebugAidl'.\r\n> Failed to find Platform SDK with path: platforms;android-R\r\n"}},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z',
#   'org': {'id': 29778334,
#    'login': 'inspireui',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/inspireui',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29778334?'}},
#  {'id': '12693296973',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 274023959,
#    'name': 'georgimorozov/k8s-jsapp-cicd',
#    'url': 'https://api.github.com/repos/georgimorozov/k8s-jsapp-cicd'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/client/axios-0.19.2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Dockerized JS App + Kubernetes + CI/CD Pipeline',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z'},
#  {'id': '12693296968',
#   'type': 'CreateEvent',
#   'actor': {'id': 65639558,
#    'login': 'sarahwi369',
#    'display_login': 'sarahwi369',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sarahwi369',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65639558?'},
#   'repo': {'id': 274024980,
#    'name': 'sarahwi369/Testing',
#    'url': 'https://api.github.com/repos/sarahwi369/Testing'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-22T02:48:53Z'},
#  {'id': '12693296991',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 149217886,
#    'name': 'AsukaSong/react-ubb-editor',
#    'url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor'},
#   'payload': {'action': 'closed',
#    'number': 954,
#    'pull_request': {'url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor/pulls/954',
#     'id': 437648481,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDM3NjQ4NDgx',
#     'html_url': 'https://github.com/AsukaSong/react-ubb-editor/pull/954',
#     'diff_url': 'https://github.com/AsukaSong/react-ubb-editor/pull/954.diff',
#     'patch_url': 'https://github.com/AsukaSong/react-ubb-editor/pull/954.patch',
#     'issue_url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor/issues/954',
#     'number': 954,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Chore(deps-dev): bump highlight.js from 10.1.0 to 10.1.1',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [highlight.js](https://github.com/highlightjs/highlight.js) from 10.1.0 to 10.1.1.\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/highlightjs/highlight.js/blob/master/CHANGES.md">highlight.js\'s changelog</a>.</em></p>\n<blockquote>\n<h2>Version 10.1.1</h2>\n<p>Fixes:</p>\n<ul>\n<li>Resolve issue on Node 6 due to dangling comma (<a href="https://github-redirect.dependabot.com/highlightjs/highlight.js/issues/2608">#2608</a>) <a href="https://github.com/ehoogerbeets">Edwin Hoogerbeets</a></li>\n<li>Resolve <code>index.d.ts is not a module</code> error (<a href="https://github-redirect.dependabot.com/highlightjs/highlight.js/issues/2603">#2603</a>) <a href="https://github.com/yyyc514">Josh Goebel</a></li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/highlightjs/highlight.js/commit/93fd0d7335e2b8b94dd122dc2898db8c86343257"><code>93fd0d7</code></a> bump v10.1.1; (chore) add changelog for 10.1.1</li>\n<li><a href="https://github.com/highlightjs/highlight.js/commit/c5783d2ffca795ccbae7045f66553adaf78303a2"><code>c5783d2</code></a> (chore) clean up types just a little</li>\n<li><a href="https://github.com/highlightjs/highlight.js/commit/a4ee4e40263aad8586bfe7d1d0fc42a0683080f7"><code>a4ee4e4</code></a> (chore) declare ambient modules for lib/core &amp; languges</li>\n<li><a href="https://github.com/highlightjs/highlight.js/commit/06565885c7c8d2717b0f8d655c3157f02551686c"><code>0656588</code></a> (chore) removed dangling comma (<a href="https://github-redirect.dependabot.com/highlightjs/highlight.js/issues/2612">#2612</a>)</li>\n<li><a href="https://github.com/highlightjs/highlight.js/commit/b1bce6e3ada485b89696f554878b2ef44a73d94a"><code>b1bce6e</code></a> (chore) more import below metadata comment</li>\n<li>See full diff in <a href="https://github.com/highlightjs/highlight.js/compare/10.1.0...10.1.1">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=highlight.js&package-manager=npm_and_yarn&previous-version=10.1.0&new-version=10.1.1)](https://dependabot.com/compatibility-score/?dependency-name=highlight.js&package-manager=npm_and_yarn&previous-version=10.1.0&new-version=10.1.1)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\nIf all status checks pass Dependabot will automatically merge this pull request.\n\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the def ...
#     'created_at': '2020-06-22T02:43:58Z',
#     'updated_at': '2020-06-22T02:48:53Z',
#     'closed_at': '2020-06-22T02:48:52Z',
#     'merged_at': '2020-06-22T02:48:52Z',
#     'merge_commit_sha': '7844d8b67b2389f07f6743459684e49dce70f703',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1120279553,
#       'node_id': 'MDU6TGFiZWwxMTIwMjc5NTUz',
#       'url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0025ff',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor/pulls/954/commits',
#     'review_comments_url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor/pulls/954/comments',
#     'review_comment_url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor/issues/954/comments',
#     'statuses_url': 'https://api.github.com/repos/AsukaSong/react-ubb-editor/statuses/805240f758580582a86653093db0b17f469ecb8d',
#     'head': {'label': 'AsukaSong:dependabot/npm_and_yarn/highlight.js-10.1.1',
#      'ref': 'dependabot/npm_and_yarn/highlight.js-10.1.1',
#      'sha': '805240f758580582a86653093db0b17f469ecb8d',
#      'user': {'login': 'AsukaSong',
#       'id': 26486891,
#       'node_id': 'MDQ6VXNlcjI2NDg2ODkx',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/26486891?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/AsukaSong',
#       'html_url': 'https://github.com/AsukaSong',
#       'followers_url': 'https://api.github.com/users/AsukaSong/followers',
#       'following_url': 'https://api.github.com/users/AsukaSong/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/AsukaSong/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/AsukaSong/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/AsukaSong/subscriptions',
#       'organizations_url': 'https://api.github.com/users/AsukaSong/orgs',
#       'repos_url': 'https://api.github.com/users/AsukaSong/repos',
#       'events_url': 'https://api.github.com/users/AsukaSong/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/AsukaSong/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 149217886,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNDkyMTc4ODY=',
#       'name': 'react-ubb-editor',
#       'full_name': 'AsukaSong/react-ubb-editor',
#       'private': False,
#       'owner': {'login': 'AsukaSong',
#        'id': 26486891,
#        'node_id': 'MDQ6VXNlcjI2NDg2ODkx',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/26486891?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/AsukaSong',
#        'html_url': 'https://github.com/AsukaSong',
#        'followers_url': 'https://api.github.com/users/AsukaSong/followers',
#        'following_url': 'https://api.github.com/users/AsukaSong/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/AsukaSong/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/AsukaSong/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/AsukaSong/subscriptions',
#        'organizations_url': 'https://api.github.com/users/AsukaSong/orgs',
# ...
#       'html_url': 'https://github.com/blocknative',
#       'followers_url': 'https://api.github.com/users/blocknative/followers',
#       'following_url': 'https://api.github.com/users/blocknative/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/blocknative/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/blocknative/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/blocknative/subscriptions',
#       'organizations_url': 'https://api.github.com/users/blocknative/orgs',
#       'repos_url': 'https://api.github.com/users/blocknative/repos',
#       'events_url': 'https://api.github.com/users/blocknative/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/blocknative/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 193790611,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM3OTA2MTE=',
#       'name': 'notify',
#       'full_name': 'blocknative/notify',
#       'private': False,
#       'owner': {'login': 'blocknative',
#        'id': 40773874,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQwNzczODc0',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/40773874?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/blocknative',
#        'html_url': 'https://github.com/blocknative',
#        'followers_url': 'https://api.github.com/users/blocknative/followers',
#        'following_url': 'https://api.github.com/users/blocknative/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/blocknative/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/blocknative/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/blocknative/subscriptions',
#        'organizations_url': 'https://api.github.com/users/blocknative/orgs',
#        'repos_url': 'https://api.github.com/users/blocknative/repos',
#        'events_url': 'https://api.github.com/users/blocknative/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/blocknative/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/blocknative/notify',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/blocknative/notify',
#       'forks_url': 'https://api.github.com/repos/blocknative/notify/forks',
#       'keys_url': 'https://api.github.com/repos/blocknative/notify/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/blocknative/notify/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/blocknative/notify/teams',
#       'hooks_url': 'https://api.github.com/repos/blocknative/notify/hooks',
#       'issue_events_url': 'https://api.github.com/repos/blocknative/notify/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/blocknative/notify/events',
#       'assignees_url': 'https://api.github.com/repos/blocknative/notify/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/blocknative/notify/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/blocknative/notify/tags',
#       'blobs_url': 'https://api.github.com/repos/blocknative/notify/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/blocknative/notify/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/blocknative/notify/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/blocknative/notify/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/blocknative/notify/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/blocknative/notify/languages',
#       'stargazers_url': 'https://api.github.com/repos/blocknative/notify/stargazers',
#       'contributors_url': 'https://api.github.com/repos/blocknative/notify/contributors',
#       'subscribers_url': 'https://api.github.com/repos/blocknative/notify/subscribers',
#       'subscription_url': 'https://api.github.com/repos/blocknative/notify/subscription',
#       'commits_url': 'https://api.github.com/repos/blocknative/notify/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/blocknative/notify/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/blocknative/notify/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/blocknative/notify/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/blocknative/notify/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/blocknative/notify/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/blocknative/notify/merges',
#       'archive_url': 'https://api.github.com/repos/blocknative/notify/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/blocknative/notify/downloads',
#       'issues_url': 'https://api.github.com/repos/blocknative/notify/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/blocknative/notify/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/blocknative/notify/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/blocknative/notify/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/blocknative/notify/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/blocknative/notify/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/blocknative/notify/deployments',
#       'created_at': '2019-06-25T22:17:21Z',
#       'updated_at': '2020-05-19T22:22:54Z',
#       'pushed_at': '2020-06-22T02:48:05Z',
#       'git_url': 'git://github.com/blocknative/notify.git',
#       'ssh_url': 'git@github.com:blocknative/notify.git',
#       'clone_url': 'https://github.com/blocknative/notify.git',
#       'svn_url': 'https://github.com/blocknative/notify',
#       'homepage': None,
#       'size': 1232,
#       'stargazers_count': 11,
#       'watchers_count': 11,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 11,
#       'default_branch': 'master'}},
#     'base': {'label': 'blocknative:master',
#      'ref': 'master',
#      'sha': '88d90cc3859035f7f9650c2d625434c61e1dc4ae',
#      'user': {'login': 'blocknative',
#       'id': 40773874,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQwNzczODc0',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/40773874?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/blocknative',
#       'html_url': 'https://github.com/blocknative',
#       'followers_url': 'https://api.github.com/users/blocknative/followers',
#       'following_url': 'https://api.github.com/users/blocknative/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/blocknative/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/blocknative/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/blocknative/subscriptions',
#       'organizations_url': 'https://api.github.com/users/blocknative/orgs',
#       'repos_url': 'https://api.github.com/users/blocknative/repos',
#       'events_url': 'https://api.github.com/users/blocknative/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/blocknative/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 193790611,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM3OTA2MTE=',
#       'name': 'notify',
#       'full_name': 'blocknative/notify',
#       'private': False,
#       'owner': {'login': 'blocknative',
#        'id': 40773874,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQwNzczODc0',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/40773874?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/blocknative',
#        'html_url': 'https://github.com/blocknative',
#        'followers_url': 'https://api.github.com/users/blocknative/followers',
#        'following_url': 'https://api.github.com/users/blocknative/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/blocknative/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/blocknative/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/blocknative/subscriptions',
#        'organizations_url': 'https://api.github.com/users/blocknative/orgs',
#        'repos_url': 'https://api.github.com/users/blocknative/repos',
#        'events_url': 'https://api.github.com/users/blocknative/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/blocknative/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/blocknative/notify',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/blocknative/notify',
#       'forks_url': 'https://api.github.com/repos/blocknative/notify/forks',
#       'keys_url': 'https://api.github.com/repos/blocknative/notify/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/blocknative/notify/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/blocknative/notify/teams',
#       'hooks_url': 'https://api.github.com/repos/blocknative/notify/hooks',
#       'issue_events_url': 'https://api.github.com/repos/blocknative/notify/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/blocknative/notify/events',
#       'assignees_url': 'https://api.github.com/repos/blocknative/notify/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/blocknative/notify/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/blocknative/notify/tags',
#       'blobs_url': 'https://api.github.com/repos/blocknative/notify/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/blocknative/notify/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/blocknative/notify/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/blocknative/notify/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/blocknative/notify/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/blocknative/notify/languages',
#       'stargazers_url': 'https://api.github.com/repos/blocknative/notify/stargazers',
#       'contributors_url': 'https://api.github.com/repos/blocknative/notify/contributors',
#       'subscribers_url': 'https://api.github.com/repos/blocknative/notify/subscribers',
#       'subscription_url': 'https://api.github.com/repos/blocknative/notify/subscription',
#       'commits_url': 'https://api.github.com/repos/blocknative/notify/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/blocknative/notify/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/blocknative/notify/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/blocknative/notify/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/blocknative/notify/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/blocknative/notify/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/blocknative/notify/merges',
#       'archive_url': 'https://api.github.com/repos/blocknative/notify/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/blocknative/notify/downloads',
#       'issues_url': 'https://api.github.com/repos/blocknative/notify/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/blocknative/notify/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/blocknative/notify/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/blocknative/notify/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/blocknative/notify/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/blocknative/notify/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/blocknative/notify/deployments',
#       'created_at': '2019-06-25T22:17:21Z',
#       'updated_at': '2020-05-19T22:22:54Z',
#       'pushed_at': '2020-06-22T02:48:05Z',
#       'git_url': 'git://github.com/blocknative/notify.git',
#       'ssh_url': 'git@github.com:blocknative/notify.git',
#       'clone_url': 'https://github.com/blocknative/notify.git',
#       'svn_url': 'https://github.com/blocknative/notify',
#       'homepage': None,
#       'size': 1232,
#       'stargazers_count': 11,
#       'watchers_count': 11,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 11,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/blocknative/notify/pulls/136'},
#      'html': {'href': 'https://github.com/blocknative/notify/pull/136'},
#      'issue': {'href': 'https://api.github.com/repos/blocknative/notify/issues/136'},
#      'comments': {'href': 'https://api.github.com/repos/blocknative/notify/issues/136/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/blocknative/notify/pulls/136/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/blocknative/notify/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/blocknative/notify/pulls/136/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/blocknative/notify/statuses/cf98d5f62e2cef976fc6e4be3b370051c36685f9'}},
#     'author_association': 'MEMBER',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 690,
#     'deletions': 617,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2020-06-22T02:48:52Z',
#   'org': {'id': 40773874,
#    'login': 'blocknative',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/blocknative',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40773874?'}},
#  {'id': '12693296895',
#   'type': 'PushEvent',
#   'actor': {'id': 133019,
#    'login': 'swankjesse',
#    'display_login': 'swankjesse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/swankjesse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/133019?'},
#   'repo': {'id': 5152285,
#    'name': 'square/okhttp',
#    'url': 'https://api.github.com/repos/square/okhttp'},
#   'payload': {'push_id': 5262913605,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/jwilson.0613.fancy_der',
#    'head': 'f3fc65798f83b91a8eead3ba22d117659b833651',
#    'before': '2cf44b68ecbb1e38453790bfecd689e5bd32c79a',
#    'commits': [{'sha': 'f3fc65798f83b91a8eead3ba22d117659b833651',
#      'author': {'email': 'jwilson@squareup.com', 'name': 'Jesse Wilson'},
#      'message': 'Early implementation of an ASN.1 DER decoder\n\nMy goal is to finish the implementation to support an ASN.1 DER encoder\nand then to change okhttp-tls to no longer depend on BouncyCastle.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/square/okhttp/commits/f3fc65798f83b91a8eead3ba22d117659b833651'}]},
#   'public': True,
#   'created_at': '2020-06-22T02:48:51Z',
#   'org': {'id': 82592,
#    'login': 'square',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/square',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82592?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008340aac31001185ecfb',
#    'text': 'Cats sleep 70% of their lives.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f87db9a11040c4a16343f',
#    'text': 'The goddess of love, beauty, and fertility in Norse mythology, Freyja was the first cat lady. She is depicted in stories as riding a chariot that was drawn by cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5894af975cdc7400113ef7f9',
#    'text': 'The technical term for a cat’s hairball is a bezoar.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b0c5e3e7ab3c50014df65fe',
#    'text': 'People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00a1a0aac31001185ed18',
#    'text': 'Cats and humans have nearly identical sections of the brain that control emotion.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e0088b0aac31001185ed09',
#    'text': "The world's largest cat measured 48.5 inches long.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '58e00b4d0aac31001185ed22',
#    'text': 'Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00a7e0aac31001185ed19',
#    'text': "A cat's cerebral cortex (the part of the brain in charge of cognitive information processing) has 300 million neurons, compared with a dog's 160 million.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b1f0aac31001185ed1e',
#    'text': 'In the 15th century, Pope Innocent VIII began ordering the killing of cats, pronouncing them demonic.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00b2b0aac31001185ed1f',
#    'text': "A cat has five toes on his front paws, and four on the back, unless he's a polydactyl.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e00be30aac31001185edfe',
#    'text': 'Cats use their whiskers to detect if they can fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58f89cff11658e00113ddd26',
#    'text': 'Cats love to eat olives or for that matter anything preserved in brine.',
#    'type': 'cat',
#    'user': {'_id': '58f89c8d11658e00113ddd24',
#     'name': {'first': 'Malvika', 'last': 'Tewari'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e83ff18f53272001515690c',
#    'type': 'cat',
#    'text': 'Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e80e7cc2d4b850015003072',
#    'type': 'cat',
#    'text': 'Cats can climb on trees faster than squirels.',
#    'user': {'_id': '5e80e6c72d4b85001500306e',
#     'name': {'first': 'Łukasz', 'last': 'Wiktorko'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eafdaf354ad960017b3703d',
#    'type': 'cat',
#    'text': 'Yjyyu.',
#    'user': {'_id': '5eafdad954ad960017b37038',
#     'name': {'first': 'Lulu', 'last': 'Dauphin'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ebbf5dd8046d00017776020',
#    'type': 'cat',
#    'text': 'Cats are fat, sometimes.',
#    'user': {'_id': '5ebbf5cd8046d0001777601f',
#     'name': {'first': 'George', 'last': 'Miguel'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec4aad30c796a00174d7b26',
#    'type': 'cat',
#    'text': 'Sss.',
#    'user': {'_id': '5ec4a7d60c796a00174d7b25',
#     'name': {'first': 'Minh', 'last': 'Nguyễn'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ec93d1de11bba0017c67e19',
#    'type': 'cat',
#    'text': 'In a sense, cats can see in the dark.',
#    'user': {'_id': '5ec93c89e11bba0017c67e18',
#     'name': {'first': 'Mandy', 'last': 'c'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb032ab0d92c0017cab214',
#    'type': 'cat',
#    'text': 'Cats are the best pets.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecb0333b0d92c0017cab215',
#    'type': 'cat',
#    'text': 'Hello cats.',
#    'user': {'_id': '5ecb02e4b0d92c0017cab213',
#     'name': {'first': 'Victor Manuel', 'last': 'Díaz de La Gasca'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ecdda946253f20017f53ec5',
#    'type': 'cat',
#    'text': 'Cats love womans, dog loves mans.',
#    'user': {'_id': '5ecdda686253f20017f53ec4',
#     'name': {'first': 'Jorge Alberto', 'last': 'Gil Rendon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece7253a0d2ec00178ae28c',
#    'type': 'cat',
#    'text': 'Cat is cat.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ece9fa9a0d2ec00178ae28e',
#    'type': 'cat',
#    'text': 'Z.',
#    'user': {'_id': '5eccdd64ba0a92001760e263',
#     'name': {'first': 'Paulius', 'last': 'Bertašius'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ed11e643c15f700172e3856',
#    'type': 'cat',
#    'text': 'Los gatos tienen más huesos que los seres humanos, nos ganan por 24.',
#    'user': {'_id': '5ed11e353c15f700172e3855',
#     'name': {'first': 'Luciano', 'last': 'Garrido Sepulveda'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eddfb501ed5570017aaf3b9',
#    'type': 'cat',
#    'text': 'Take a try.',
#    'user': {'_id': '5eddfb351ed5570017aaf3b8',
#     'name': {'first': 'calix', 'last': 'cheng'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eebc851515a030017471024',
#    'type': 'cat',
#    'text': 'Cats are cats.',
#    'user': {'_id': '5eebc848515a030017471023',
#     'name': {'first': 'Ricky', 'last': 'Chon'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5ea7496761cd4d0017498a94',
#    'type': 'cat',
#    'text': 'Ancient sailors believed that cats were magic and would often risk their own lives, even in an "every man for himself" situation, to save a cat from a sinking ship. All ships had at least one ship\'s cat as cats would eat the rats that have always plagued ships. The ship\'s cat would often be given a rank and sailors would generally take excessively good care of their cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5eaafca69105ce00177573de',
#    'type': 'cat',
#    'text': 'Cats sleep most of the time.',
#    'user': {'_id': '5ea977d1cd53d20017d7d8b2',
#     'name': {'first': 'Quang', 'last': 'Pham'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
